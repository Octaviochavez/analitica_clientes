# %% [markdown]
# <a href="https://colab.research.google.com/github/Octaviochavez/analitica_clientes/blob/main/Proyecto_Progra_Cienc_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importe de librerias necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, OrdinalEncoder
#Lectura de datos sucios del data set
data = pd.read_csv('dataset_clientes.csv')
data.head()
# Out:
#    id_cliente fecha_registro  edad     genero  region estado_civil  \
# 0           1     2021-10-27    66       Otro   Norte   Divorciado
# 1           2     2018-08-25    51  Masculino  Centro      Soltero
# 2           3     2019-05-25    48   Femenino   Norte       Casado
# 3           4     2022-04-20    54  Masculino     Sur       Casado
# 4           5     2020-03-19    31       Otro  Centro      Soltero
#
#    ingreso_mensual  gasto_mensual   deuda_total  score_crediticio  ...  \
# 0     9.243057e+05  524088.303055  2.448145e+06        455.406680  ...
# 1     1.384687e+06  314259.751474  1.620569e+06        575.048508  ...
# 2              NaN  387192.316142  5.395040e+06        770.716904  ...
# 3     4.369032e+05  417328.601856  2.999350e+06        442.722671  ...
# 4     7.408561e+05  490961.191253  1.637711e+06        468.188403  ...
#
#    ultima_compra_dias  uso_app  tipo_plan num_productos tiene_tarjeta_credito  \
# 0                 356     Bajo   Estandar             3                     1
# 1                 307    Medio    Premium             4                     1
# 2                 232     Alto    Premium             4                     1
# 3                 165     Alto   Estandar             2                     1
# 4                 283     Bajo   Estandar             3                     1
#
#    canal_registro  dia_semana_registro hora_registro codigo_postal  abandono
# 0          Tienda                Lunes            22          3824         1
# 1             App               Martes            10          4148         0
# 2             App               Jueves             6          7200         0
# 3             App              Domingo            16          1782         1
# 4             Web               Martes             8          3448         1
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Analisis de tipos de datos de cada categoria (columna)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20400 entries, 0 to 20399
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_cliente             20400 non-null  int64
#  1   fecha_registro         20400 non-null  object
#  2   edad                   20400 non-null  int64
#  3   genero                 20400 non-null  object
#  4   region                 20400 non-null  object
#  5   estado_civil           20400 non-null  object
#  6   ingreso_mensual        19379 non-null  float64
#  7   gasto_mensual          19375 non-null  float64
#  8   deuda_total            20400 non-null  float64
#  9   score_crediticio       19379 non-null  float64
#  10  antiguedad_meses       20400 non-null  int64
#  11  frecuencia_compra      20400 non-null  int64
#  12  ultima_compra_dias     20400 non-null  int64
#  13  uso_app                20400 non-null  object
#  14  tipo_plan              20400 non-null  object
#  15  num_productos          20400 non-null  int64
#  16  tiene_tarjeta_credito  20400 non-null  int64
#  17  canal_registro         20400 non-null  object
#  18  dia_semana_registro    20400 non-null  object
#  19  hora_registro          20400 non-null  int64
#  20  codigo_postal          20400 non-null  int64
#  21  abandono               20400 non-null  int64
# dtypes: float64(4), int64(10), object(8)
# memory usage: 3.4+ MB

# %% [markdown]
# ## Descripcion analisis valores columnas cuantitativas
# Identificamos que las columnas "tiene_tarjeta_credito" y "abandono" debe ser booleano y no entero, ya que sus valores o son 1 o son 0.

# %%
data.drop(columns=["id_cliente"]).describe()
# Out:
#               edad  ingreso_mensual  gasto_mensual   deuda_total  \
# count  20400.00000     1.937900e+04   19375.000000  2.040000e+04
# mean      48.54598     8.330390e+05  399453.495188  2.061953e+06
# std       17.84971     4.301978e+05  150831.135171  1.055155e+06
# min       18.00000    -8.302577e+04 -194957.467079 -1.684124e+06
# 25%       33.00000     6.346396e+05  296753.420113  1.461942e+06
# 50%       48.00000     8.044483e+05  398887.260180  2.017759e+06
# 75%       64.00000     9.737937e+05  500485.426137  2.557871e+06
# max       79.00000     7.560936e+06  954575.217321  1.777694e+07
#
#        score_crediticio  antiguedad_meses  frecuencia_compra  \
# count      19379.000000      20400.000000       20400.000000
# mean         600.441593         60.205882           9.966765
# std          100.408685         34.210052           5.460586
# min          220.516968          1.000000           1.000000
# 25%          532.872163         31.000000           5.000000
# 50%          600.955064         61.000000          10.000000
# 75%          668.245607         90.000000          15.000000
# max          998.290682        119.000000          19.000000
#
#        ultima_compra_dias  num_productos  tiene_tarjeta_credito  \
# count        20400.000000   20400.000000           20400.000000
# mean           182.325686       2.994853               0.501373
# std            105.056827       1.410716               0.500010
# min              1.000000       1.000000               0.000000
# 25%             92.000000       2.000000               0.000000
# 50%            181.000000       3.000000               1.000000
# 75%            274.000000       4.000000               1.000000
# max            364.000000       5.000000               1.000000
#
#        hora_registro  codigo_postal      abandono
# count   20400.000000   20400.000000  20400.000000
# mean       11.416716    5488.970147      0.396814
# std         6.891420    2602.374998      0.489249
# min         0.000000    1000.000000      0.000000
# 25%         6.000000    3239.000000      0.000000
# 50%        11.000000    5477.500000      0.000000
# 75%        17.000000    7775.000000      1.000000
# max        23.000000    9998.000000      1.000000

# %% [markdown]
# ## Descripcion y analisis columnas cualitativas
# columnas ordinales: "uso_app","tipo_plan"
#
# columnas nominales: "genero","region","estado_civil","canal_registro","dia_semana_registro"

# %%
data.describe(include="object")
# Out:
#        fecha_registro genero region estado_civil uso_app tipo_plan  \
# count           20400  20400  20400        20400   20400     20400
# unique           2000      3      3            3       3         3
# top        2022-04-09   Otro    Sur       Casado    Bajo  Estandar
# freq               21   6997   6812         6828    6886      6878
#
#        canal_registro dia_semana_registro
# count           20400               20400
# unique              3                   7
# top               App           Miercoles
# freq             6894                3000

# %%
data.region.unique()
# Out:
# array(['Norte', 'Centro', 'Sur'], dtype=object)

# %%
data.estado_civil.unique()
# Out:
# array(['Divorciado', 'Soltero', 'Casado'], dtype=object)

# %%
data.tipo_plan.unique()
# Out:
# array(['Estandar', 'Premium', 'Basico'], dtype=object)

# %%
data.uso_app.unique()
# Out:
# array(['Bajo', 'Medio', 'Alto'], dtype=object)

# %%
data.canal_registro.unique()
# Out:
# array(['Tienda', 'App', 'Web'], dtype=object)

# %%
data.genero.unique()
# Out:
# array(['Otro', 'Masculino', 'Femenino'], dtype=object)

# %% [markdown]
# ##Analisis de nulos
# Determinamos que "ingreso_mensual" ,"gastomensual"y"score_crediticio" contienen la misma cantidad de nulos.

# %%
data.isnull().sum()
#Obtencion de datos nulos
# Out:
# id_cliente                  0
# fecha_registro              0
# edad                        0
# genero                      0
# region                      0
# estado_civil                0
# ingreso_mensual          1021
# gasto_mensual            1025
# deuda_total                 0
# score_crediticio         1021
# antiguedad_meses            0
# frecuencia_compra           0
# ultima_compra_dias          0
# uso_app                     0
# tipo_plan                   0
# num_productos               0
# tiene_tarjeta_credito       0
# canal_registro              0
# dia_semana_registro         0
# hora_registro               0
# codigo_postal               0
# abandono                    0
# dtype: int64

# %% [markdown]
# ##Analisis de duplicados

# %%
data.duplicated().sum()
#Obtencion de duplicados
data[data.duplicated(keep=False)].sort_values(by='id_cliente')
# Out:
#        id_cliente fecha_registro  edad     genero  region estado_civil  \
# 20032         178     2022-02-16    58       Otro  Centro      Soltero
# 177           178     2022-02-16    58       Otro  Centro      Soltero
# 215           216     2021-05-23    77   Femenino  Centro   Divorciado
# 20300         216     2021-05-23    77   Femenino  Centro   Divorciado
# 20348         327     2019-07-15    43   Femenino     Sur      Soltero
# ...           ...            ...   ...        ...     ...          ...
# 19921       19922     2020-01-22    52  Masculino     Sur       Casado
# 19923       19924     2018-01-17    54       Otro  Centro       Casado
# 20289       19924     2018-01-17    54       Otro  Centro       Casado
# 20147       19983     2022-02-17    26       Otro  Centro      Soltero
# 19982       19983     2022-02-17    26       Otro  Centro      Soltero
#
#        ingreso_mensual  gasto_mensual   deuda_total  score_crediticio  ...  \
# 20032    574734.320058  124060.694605  1.567047e+06        706.773275  ...
# 177      574734.320058  124060.694605  1.567047e+06        706.773275  ...
# 215      696251.283767  755824.522948  2.522168e+06        691.380909  ...
# 20300    696251.283767  755824.522948  2.522168e+06        691.380909  ...
# 20348    611018.691110  238932.156632  8.764364e+05        618.183493  ...
# ...                ...            ...           ...               ...  ...
# 19921    892522.042338  161697.180367  1.750559e+06        662.274443  ...
# 19923    822109.701169  489936.535727  2.022070e+06        584.830157  ...
# 20289    822109.701169  489936.535727  2.022070e+06        584.830157  ...
# 20147    947809.404071  221838.916723  3.226056e+06        556.285263  ...
# 19982    947809.404071  221838.916723  3.226056e+06        556.285263  ...
#
#        ultima_compra_dias  uso_app  tipo_plan num_productos  \
# 20032                 133     Alto    Premium             2
# 177                   133     Alto    Premium             2
# 215                   217     Alto   Estandar             5
# 20300                 217     Alto   Estandar             5
# 20348                 303    Medio     Basico             3
# ...                   ...      ...        ...           ...
# 19921                 274     Bajo    Premium             1
# 19923                 145     Bajo   Estandar             1
# 20289                 145     Bajo   Estandar             1
# 20147                 361     Alto     Basico             1
# 19982                 361     Alto     Basico             1
#
#       tiene_tarjeta_credito  canal_registro  dia_semana_registro  \
# 20032                     0          Tienda               Sabado
# 177                       0          Tienda               Sabado
# 215                       1             App               Sabado
# 20300                     1             App               Sabado
# 20348                     0             App                Lunes
# ...                     ...             ...                  ...
# 19921                     0             App              Viernes
# 19923                     0          Tienda            Miercoles
# 20289                     0          Tienda            Miercoles
# 20147                     1          Tienda               Jueves
# 19982                     1          Tienda               Jueves
#
#       hora_registro codigo_postal  abandono
# 20032            11          8146         1
# 177              11          8146         1
# 215               6          4541         1
# 20300             6          4541         1
# 20348            11          6291         0
# ...             ...           ...       ...
# 19921             3          4398         1
# 19923            17          8097         1
# 20289            17          8097         1
# 20147             5          6118         1
# 19982             5          6118         1
#
# [800 rows x 22 columns]

# %% [markdown]
# ##Analisis de atipicos
# Definimos que "tiene_tarjeta_credito"y"abandono" no son candidatos para la busqueda de atipicos, ya que cuentan como categoricos (booleanos).
# Además podemos identificar las columnas "ingreso_mensual",	"gasto_mensual",	"deuda_total",	"score_crediticio" con alta probabilidad de tener datos atipicos.

# %%
registro_atipicos=["edad",	"ingreso_mensual",	"gasto_mensual",	"deuda_total",	"score_crediticio",	"antiguedad_meses",	"frecuencia_compra",	"ultima_compra_dias",	"num_productos",	"hora_registro"]
fig, axes = plt.subplots(1, 10, figsize=(20,20))
axes = axes.flatten()  # convierte la matriz de ejes en un vector
for i, col in enumerate(registro_atipicos):
  data[col].plot(kind='box',figsize=(12,12), ax=axes[i])
  axes[i].tick_params(axis="x", labelrotation=45)

plt.suptitle("Análisis de atípicos", fontsize=16, fontweight="bold")
plt.tight_layout()

plt.show()

# %% [markdown]
# ##Clase para winsorizar los datos
# Esto con el fin de limpiar los outliers.

# %%
class Winsorizer(BaseEstimator, TransformerMixin):

  def __init__(self, limits=(0.05, 0.05)):
    self.limits = limits

  def fit(self, X, y=None):
    # Guardar nombres si es DataFrame, si no generar nombres genéricos
    if isinstance(X, pd.DataFrame):
      self.columns_ = X.columns
    else:
      self.columns_ = np.arange(X.shape[1])
    return self

  def transform(self, X):
    X = pd.DataFrame(X, columns=self.columns_)
    for col in self.columns_:
      lower = X[col].quantile(self.limits[0])
      upper = X[col].quantile(1 - self.limits[1])
      X = X.astype("float64")
      X[col] = np.clip(X[col], lower, upper)
    return X

  def get_feature_names_out(self, input_features=None):
    if input_features is None:
      return np.array(self.columns_)
    else:
      return np.array(input_features)
